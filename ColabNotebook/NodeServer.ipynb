# %% [markdown]
# ## Code To setup Development Server

# %%
# !apt-get update
# !curl -sL https://deb.nodesource.com/setup_10.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# !node -v
# !npm -v
# !git clone https://github.com/Eldhose-K-A/alyce-server.git
import os
os.chdir('/content/alyce-server')
# !npm install --save

# %% [markdown]
# ## Code To Start Node Server and Ngrok and Obtain ngrok Link

# %%
# !wget --quiet https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
# !unzip -u ngrok-stable-linux-amd64.zip
# !chmod +x ngrok

get_ipython().system_raw(
    'npm start > logs.txt 2>&1 &'
)

get_ipython().system_raw(
    './ngrok http {} &'
    .format(3000)
)
public_url = !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
print(public_url[0])

# %%
# !cat logs.txt

# %%
# !git pull

# %% [markdown]
# ## In Case of Emergency (To stop Server)

# %% [markdown]
# Use the below command to find the PID of ngrok and node

# %%
# !sudo lsof -i:3000

# %% [markdown]
# Use 'kill &lt;PID&gt;' to kill the process.

# %%
#!kill <PID>

# %%
# !kill ----

# %% [markdown]
# Use the below code to restart Server after stoping using above code.

# %%
get_ipython().system_raw(
    'npm start > logs.txt 2>&1 &'
)
